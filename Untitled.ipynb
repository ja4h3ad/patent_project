# %%
import pyodbc # database connector
import pandas as pd # read the csv file into a dataframe
df = pd.read_csv("nw_patents_seed.csv")
# Some other example server values are
# server = 'localhost\sqlexpress' # for a named instance
# server = 'myserver,port' # to specify an alternate port

# %%
df
# Out:
#                    pID                                              title  \
# 0     US-2007167700-A1  Method for accurate in vivo delivery of a ther...
# 1       CN-112998859-B  Key point space measurement control method and...
# 2       US-11045271-B1                            Robotic medical system
# 3       CN-112991409-B  Skeleton registration method and system and st...
# 4     US-2018263697-A1  Image and laser guided control of cutting usin...
# 5        EP-3439558-B1  System for providing probe trace fiducial-free...
# 6     US-2022031401-A1  System and method for preventing wrong-site su...
# 7     WO-2012072112-A1                  Tracking of a medical instrument
# 8     US-2016158938-A1  Method and device for defining a working range...
# 9     US-2021235991-A1                Multispectral synchronized imaging
# 10      CN-109498156-A  A kind of head operation air navigation aid ba...
# 11    US-2021068784-A1  System for tracking and imaging a treatment pr...
# 12    US-2020360100-A1  Robotic arms and methods for tissue resection ...
# 13    US-2020367970-A1  System and method for multi-client deployment ...
# 14      US-10554820-B2  Route an emergency call over VoIP client to ce...
# 15    WO-2016051015-A1  System and method for configuring communicatio...
# 16      CN-108881239-B  Software telephone, roaming method thereof and...
# 17      CN-105245509-A  Method for establishing bidirectional data tra...
# 18      US-10986219-B2             LTE fault-tolerant signaling approach
# 19    US-2013138820-A1  Communication equipment that performs communic...
# 20      US-10673908-B2  Devices and systems for voice over internet pr...
# 21      CN-109040007-B  Method and system for handling Alternative Net...
# 22         TW-498662-B     Communication method and communication device
# 23  DE-102007011259-A1  Personal communication partner choosing and di...
# 24        AU-776055-B2  Method for providing IP telephony with QoS usi...
# 25       FR-2865048-A1  Electronic business card transmission process,...
# 26      US-10673982-B2  Cloud-based application communication with hie...
# 27      US-10728438-B1   Distributed video and network camera management
# 28      US-10567593-B1    Integrated VoIP and RoIP communication network
# 29    WO-2013077601-A1  Method and apparatus for controlling voice com...
# 30  DE-102007037489-A1  Method for assembling or executing audio or vi...
#
#                                              inventor publicationDate  \
# 0               Norbert Rahn, Jan Boese, Martin Kleen         7/19/07
# 1   ËåÉË°†, ËÉ°ÂÜõ, ÈôàÊ¥™Ê±ü, ÂÆÅ‰∏∫Âçö, ÈªÑÊñáÂÆ...         4/26/22
# 2                                          Bao Q Tran         6/29/21
# 3                                ÊûóÂøÖË¥µ, M¬∑Êù∞Ê£Æ         7/30/21
# 4         Justin Eskesen, Micah Forstein, Joel Zuhars         9/20/18
# 5                                    Scott A. Merritt          6/2/21
# 6   Kaveh Khajavi, II David E. Lane, Luke Boland, ...          2/3/22
# 7                                    Malcolm Williams          6/7/12
# 17  https://patents.google.com/patent/CN105245509A/en
# 18  https://patents.google.com/patent/US10986219B2/en
# 19  https://patents.google.com/patent/US2013013882...
# 20  https://patents.google.com/patent/US10673908B2/en
# 21  https://patents.google.com/patent/CN109040007B/en
# 22     https://patents.google.com/patent/TW498662B/en
# 23  https://patents.google.com/patent/DE1020070112...
# 24    https://patents.google.com/patent/AU776055B2/en
# 25   https://patents.google.com/patent/FR2865048A1/en
# 26  https://patents.google.com/patent/US10673982B2/en
# 27  https://patents.google.com/patent/US10728438B1/en
# 28  https://patents.google.com/patent/US10567593B1/en
# 29  https://patents.google.com/patent/WO2013077601...
# 30  https://patents.google.com/patent/DE1020070374...

# %%
df.head()
# Out:
#                 pID                                              title  \
# 0  US-2007167700-A1  Method for accurate in vivo delivery of a ther...
# 1    CN-112998859-B  Key point space measurement control method and...
# 2    US-11045271-B1                            Robotic medical system
# 3    CN-112991409-B  Skeleton registration method and system and st...
# 4  US-2018263697-A1  Image and laser guided control of cutting usin...
#
#                                             inventor publicationDate  \
# 0              Norbert Rahn, Jan Boese, Martin Kleen         7/19/07
# 1  ËåÉË°†, ËÉ°ÂÜõ, ÈôàÊ¥™Ê±ü, ÂÆÅ‰∏∫Âçö, ÈªÑÊñáÂÆ...         4/26/22
# 2                                         Bao Q Tran         6/29/21
# 3                               ÊûóÂøÖË¥µ, M¬∑Êù∞Ê£Æ         7/30/21
# 4        Justin Eskesen, Micah Forstein, Joel Zuhars         9/20/18
#
#                                           resultLink
# 0  https://patents.google.com/patent/US2007016770...
# 1  https://patents.google.com/patent/CN112998859B/en
# 2  https://patents.google.com/patent/US11045271B1/en
# 3  https://patents.google.com/patent/CN112991409B/en
# 4  https://patents.google.com/patent/US2018026369...

# %%
import mysql.connector as msql
from mysql.connector import Error
try:
    conn = mysql.connect(host='localhost', database='patents', user='root', password='root')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS employee_data;')
        print('Creating table....')
# in the below line please pass the create table statement which you want #to create
        cursor.execute("CREATE TABLE employee_data(first_name varchar(255),last_name varchar(255),company_name varchar(255),address varchar(255),city varchar(255),county varchar(255),state varchar(255),zip int,phone1 varchar(255),phone2 varchar(255),email varchar(255),web varchar(255))")
        print("Table is created....")
        #loop through the data frame
        for i,row in empdata.iterrows():
            #here %S means string values 
            sql = "INSERT INTO employee.employee_data VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
            
except Error as e:
            print("Error while connecting to MySQL", e)
